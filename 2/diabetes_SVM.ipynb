# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/HW/ML/Dataset/diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe(include='all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
np.unique(data.Outcome, return_counts=True)
# Out:
# (array([0, 1]), array([500, 268]))

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
for col in data.columns[:-1]:
    sns.displot(data=data, x=col, col=data.Outcome)
    plt.show

# %%
columns = data.columns[:-1]

# %%
pairs = [(col1, col2) for i, col1 in enumerate(columns) for col2 in columns[i+1:]]


fig, axes = plt.subplots(7, 4, figsize=(20, 15))
axes = axes.flatten()


for idx, (col1, col2) in enumerate(pairs):
    sns.scatterplot(data=data, x=col1, y=col2, ax=axes[idx])
    axes[idx].set_title(f"{col1} vs {col2}", fontsize=10)
    axes[idx].set_xlabel(col1, fontsize=8)
    axes[idx].set_ylabel(col2, fontsize=8)

if len(pairs) < len(axes):
    for ax in axes[len(pairs):]:
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
data[data['SkinThickness']>80]
data.drop(index=579, axis=0, inplace=True)

# %%
SkinThickness_zero1 = data.query('SkinThickness == 0 and Outcome == 1')
SkinThickness_zero1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# 15             7      100              0              0        0  30.0
# 17             7      107             74              0        0  29.6
# ..           ...      ...            ...            ...      ...   ...
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# 9                       0.232   54        1
# 11                      0.537   34        1
# 15                      0.484   32        1
# 17                      0.254   31        1
# ..                        ...  ...      ...
# 749                     0.178   50        1
# 750                     1.182   22        1
# 757                     0.258   52        1
# 759                     0.278   66        1
# 766                     0.349   47        1
#
# [88 rows x 9 columns]

# %%
SkinThickness_zero0 = data.query('SkinThickness == 0 and Outcome == 0')
SkinThickness_zero0
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# 12            10      139             80              0        0  27.1
# 21             8       99             84              0        0  35.4
# ..           ...      ...            ...            ...      ...   ...
# 728            2      175             88              0        0  22.9
# 729            2       92             52              0        0  30.1
# 734            2      105             75              0        0  23.3
# 758            1      106             76              0        0  37.5
# 762            9       89             62              0        0  22.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 5                       0.201   30        0
# 7                       0.134   29        0
# 10                      0.191   30        0
# 12                      1.441   57        0
# 21                      0.388   50        0
# ..                        ...  ...      ...
# 728                     0.326   22        0
# 729                     0.141   22        0
# 734                     0.560   53        0
# 758                     0.197   26        0
# 762                     0.142   33        0
#
# [139 rows x 9 columns]

# %%
data2 = data.query('SkinThickness != 0 and Glucose != 0 and BloodPressure != 0 and BMI != 0')

# %%
sns.heatmap(data2.corr(), annot=True)
# Out:
# <Axes: >

# %%
df1 = data2.query('Outcome == 1')
df2 = data2.query('Outcome == 0')

# %%
df1.mean()
# Out:
# Pregnancies                   4.715909
# Glucose                     142.812500
# BloodPressure                74.727273
# SkinThickness                32.602273
# Insulin                     152.784091
# BMI                          35.826136
# DiabetesPedigreeFunction      0.616824
# Age                          36.267045
# Outcome                       1.000000
# dtype: float64

# %%
df2.mean()
# Out:
# Pregnancies                   2.926761
# Glucose                     110.016901
# BloodPressure                69.912676
# SkinThickness                27.290141
# Insulin                      96.574648
# BMI                          31.429577
# DiabetesPedigreeFunction      0.446315
# Age                          29.222535
# Outcome                       0.000000
# dtype: float64

# %%
SkinThickness_zero1 = SkinThickness_zero1.replace({'SkinThickness': {0:32.6}, 'Insulin': {0:152.78}, 'BMI': {0:35.83}, 'BloodPressure':{0:74.72}})
SkinThickness_zero1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 2              8      183          64.00           32.6   152.78  23.30
# 9              8      125          96.00           32.6   152.78  35.83
# 11            10      168          74.00           32.6   152.78  38.00
# 15             7      100          74.72           32.6   152.78  30.00
# 17             7      107          74.00           32.6   152.78  29.60
# ..           ...      ...            ...            ...      ...    ...
# 749            6      162          62.00           32.6   152.78  24.30
# 750            4      136          70.00           32.6   152.78  31.20
# 757            0      123          72.00           32.6   152.78  36.30
# 759            6      190          92.00           32.6   152.78  35.50
# 766            1      126          60.00           32.6   152.78  30.10
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# 9                       0.232   54        1
# 11                      0.537   34        1
# 15                      0.484   32        1
# 17                      0.254   31        1
# ..                        ...  ...      ...
# 749                     0.178   50        1
# 750                     1.182   22        1
# 757                     0.258   52        1
# 759                     0.278   66        1
# 766                     0.349   47        1
#
# [88 rows x 9 columns]

# %%
SkinThickness_zero0 = SkinThickness_zero0.replace({'SkinThickness': {0:27.29}, 'Insulin': {0:96.57}, 'BMI': {0:31.43}, 'BloodPressure':{0:69.91}})
SkinThickness_zero0
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5              5      116          74.00          27.29    96.57  25.6
# 7             10      115          69.91          27.29    96.57  35.3
# 10             4      110          92.00          27.29    96.57  37.6
# 12            10      139          80.00          27.29    96.57  27.1
# 21             8       99          84.00          27.29    96.57  35.4
# ..           ...      ...            ...            ...      ...   ...
# 728            2      175          88.00          27.29    96.57  22.9
# 729            2       92          52.00          27.29    96.57  30.1
# 734            2      105          75.00          27.29    96.57  23.3
# 758            1      106          76.00          27.29    96.57  37.5
# 762            9       89          62.00          27.29    96.57  22.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 5                       0.201   30        0
# 7                       0.134   29        0
# 10                      0.191   30        0
# 12                      1.441   57        0
# 21                      0.388   50        0
# ..                        ...  ...      ...
# 728                     0.326   22        0
# 729                     0.141   22        0
# 734                     0.560   53        0
# 758                     0.197   26        0
# 762                     0.142   33        0
#
# [139 rows x 9 columns]

# %%
new_data = pd.concat([SkinThickness_zero0, SkinThickness_zero1, data2])

# %%
new_data = new_data.reset_index(drop=True)

# %%
sns.heatmap(new_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.impute import KNNImputer

# %%
data_nan = data.replace({'Glucose': {0:np.nan}, 'BloodPressure': {0:np.nan}, 'SkinThickness': {0:np.nan}, 'BMI': {0:np.nan}, 'Insulin': {0:np.nan}})

# %%
data_nan
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [767 rows x 9 columns]

# %%
Imputer = KNNImputer(n_neighbors= 3 )
fd_filled = Imputer.fit_transform(data_nan[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']])

# %%
fd_filled = pd.DataFrame(fd_filled)
fd_filled
# Out:
#          0     1          2           3     4
# 0    148.0  72.0  35.000000  241.666667  33.6
# 1     85.0  66.0  29.000000   90.333333  26.6
# 2    183.0  64.0  30.666667  555.333333  23.3
# 3     89.0  66.0  23.000000   94.000000  28.1
# 4    137.0  40.0  35.000000  168.000000  43.1
# ..     ...   ...        ...         ...   ...
# 762  101.0  76.0  48.000000  180.000000  32.9
# 763  122.0  70.0  27.000000  155.000000  36.8
# 764  121.0  72.0  23.000000  112.000000  26.2
# 765  126.0  60.0  18.666667  215.333333  30.1
# 766   93.0  70.0  31.000000   65.333333  30.4
#
# [767 rows x 5 columns]

# %%
fd_filled.rename({0:'Glucose', 1:'BloodPressure', 2:'SkinThickness', 3:'Insulin', 4:'BMI'}, axis=1, inplace=True)

# %%
fd_filled.insert(0, 'Pregnancies', data['Pregnancies'], True)
fd_filled.insert(6, 'DiabetesPedigreeFunction', data['DiabetesPedigreeFunction'], True)
fd_filled.insert(7, 'Age', data['Age'], True)
fd_filled.insert(8, 'Outcome', data['Outcome'], True)

# %%
fd_filled
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6.0    148.0           72.0      35.000000  241.666667  33.6
# 1            1.0     85.0           66.0      29.000000   90.333333  26.6
# 2            8.0    183.0           64.0      30.666667  555.333333  23.3
# 3            1.0     89.0           66.0      23.000000   94.000000  28.1
# 4            0.0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 762          9.0    101.0           76.0      48.000000  180.000000  32.9
# 763         10.0    122.0           70.0      27.000000  155.000000  36.8
# 764          2.0    121.0           72.0      23.000000  112.000000  26.2
# 765          5.0    126.0           60.0      18.666667  215.333333  30.1
# 766          1.0     93.0           70.0      31.000000   65.333333  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0      1.0
# 1                       0.351  31.0      0.0
# 2                       0.672  32.0      1.0
# 3                       0.167  21.0      0.0
# 4                       2.288  33.0      1.0
# ..                        ...   ...      ...
# 762                     0.142  33.0      0.0
# 763                     0.171  63.0      0.0
# 764                     0.340  27.0      0.0
# 765                     0.245  30.0      0.0
# 766                     0.349  47.0      1.0
#
# [767 rows x 9 columns]

# %%
fd_filled[fd_filled['SkinThickness']>80]
fd_filled.drop(index=579, axis=0, inplace=True)

# %%
sns.heatmap(fd_filled.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Here we normalize the data by replacing $x$ with $ (x-\mu)/\sigma $ where $\mu$ is the mean of the particular column and $\sigma$ is the standard deviation.

# %%
def normalizition(data, col):
    miu = data[col].mean()
    sigma = data[col].std()
    data[col] = (data[col] - miu) / sigma
    return data

# %%
df = new_data.copy()
for i in df.columns[:-1]:
    df = normalizition(df, i)
df
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.340574 -0.185523       0.128928      -0.216138 -0.188210 -0.992564
# 1       1.827642 -0.218334      -0.207859      -0.216138 -0.188210  0.413785
# 2       0.043160 -0.382387       1.611124      -0.216138 -0.188210  0.747249
# 3       1.827642  0.569123       0.622993      -0.216138 -0.188210 -0.775087
# 4       1.232815 -0.743305       0.952370      -0.216138 -0.188210  0.428284
# ..           ...       ...            ...            ...       ...       ...
# 753     1.530228  1.586254       0.128928       0.217309 -1.116463  1.675150
# 754     1.827642 -0.677684       0.293617       2.203452  0.613739  0.065823
# 755    -0.551667  0.011341      -0.200448      -0.250019 -1.116463  0.631262
# 756     0.340574 -0.021470      -0.035760      -0.717347 -0.039893 -0.905573
# 757    -0.849081 -0.940169      -0.200448       0.217309 -1.116463 -0.296639
#
#      DiabetesPedigreeFunction       Age  Outcome
# 0                   -0.816092 -0.277958        0
# 1                   -1.019336 -0.363156        0
# 2                   -0.846427 -0.277958        0
# 3                    2.945448  2.022364        0
# 4                   -0.248827  1.425984        0
# ..                        ...       ...      ...
# 753                 -0.203325  0.829604        1
# 754                 -0.907097  2.533547        0
# 755                 -0.394435 -0.533550        0
# 756                 -0.682618 -0.277958        0
# 757                 -0.470273 -0.874338        0
#
# [758 rows x 9 columns]

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
X = df.drop('Outcome', axis = 1)
y = df.Outcome
X
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.340574 -0.185523       0.128928      -0.216138 -0.188210 -0.992564
# 1       1.827642 -0.218334      -0.207859      -0.216138 -0.188210  0.413785
# 2       0.043160 -0.382387       1.611124      -0.216138 -0.188210  0.747249
# 3       1.827642  0.569123       0.622993      -0.216138 -0.188210 -0.775087
# 4       1.232815 -0.743305       0.952370      -0.216138 -0.188210  0.428284
# ..           ...       ...            ...            ...       ...       ...
# 753     1.530228  1.586254       0.128928       0.217309 -1.116463  1.675150
# 754     1.827642 -0.677684       0.293617       2.203452  0.613739  0.065823
# 755    -0.551667  0.011341      -0.200448      -0.250019 -1.116463  0.631262
# 756     0.340574 -0.021470      -0.035760      -0.717347 -0.039893 -0.905573
# 757    -0.849081 -0.940169      -0.200448       0.217309 -1.116463 -0.296639
#
#      DiabetesPedigreeFunction       Age
# 0                   -0.816092 -0.277958
# 1                   -1.019336 -0.363156
# 2                   -0.846427 -0.277958
# 3                    2.945448  2.022364
# 4                   -0.248827  1.425984
# ..                        ...       ...
# 753                 -0.203325  0.829604
# 754                 -0.907097  2.533547
# 755                 -0.394435 -0.533550
# 756                 -0.682618 -0.277958
# 757                 -0.470273 -0.874338
#
# [758 rows x 8 columns]

# %%
from sklearn.model_selection import GridSearchCV

# %%
model_params  = {
    "svm": {
        "model": SVC(),
        "params": {
            "C": [0.1, 0.5, 1, 5, 10],
            "kernel": ["rbf", "linear", "poly"],
            "gamma": ["scale", 0.1, 0.01, 0.001],
            "degree": [2, 3, 4]
        }
      }
  }

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state= 111)

# %%
model = model_params["svm"]["model"]
params = model_params["svm"]["params"]

# %%
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 0.5, 1, 5, 10], 'degree': [2, 3, 4],
#                          'gamma': ['scale', 0.1, 0.01, 0.001],
#                          'kernel': ['rbf', 'linear', 'poly']},
#              scoring='accuracy')

# %%
results = pd.DataFrame(grid_search.cv_results_)

results_table = results[["param_C", "param_kernel", "param_gamma", "param_degree", "mean_test_score"]]
results_table = results_table.sort_values(by="mean_test_score", ascending=False)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Score:", grid_search.best_score_)

print("\nDetailed Scores for All Parameter Combinations:")
print(results_table)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)

test_score = accuracy_score(y_test, best_model.predict(x_test))
print("\nTest Accuracy on Test Data:", test_score)
# Out:
# Best Parameters: {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# Best Cross-Validation Score: 0.7789188456848666
#
# Detailed Scores for All Parameter Combinations:
#      param_C param_kernel param_gamma  param_degree  mean_test_score
# 96       1.0          rbf       scale             4         0.778919
# 72       1.0          rbf       scale             2         0.778919
# 84       1.0          rbf       scale             3         0.778919
# 120      5.0          rbf       scale             3         0.778838
# 108      5.0          rbf       scale             2         0.778838
# ..       ...          ...         ...           ...              ...
# 47       0.5         poly       0.001             2         0.651822
# 44       0.5         poly        0.01             2         0.651822
# 35       0.1         poly       0.001             4         0.651822
# 33       0.1          rbf       0.001             4         0.651822
# 179     10.0         poly       0.001             4         0.651822
#
# [180 rows x 5 columns]
#
# Test Accuracy on Test Data: 0.8223684210526315

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
percentage_matrix = (cm / cm.sum().sum())

# Plot the confusion matrix using Seaborn with percentages
plt.figure(figsize=(8, 6))
sns.heatmap(percentage_matrix, annot=True, fmt='.2%', cmap='Blues', cbar=False,
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['True Negative', 'True Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (Percentages)')
plt.show()
